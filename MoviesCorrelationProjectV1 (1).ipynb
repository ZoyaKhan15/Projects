# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



#read in data
file_to_open = os.path.expanduser('~/Desktop/movies.csv')
df = pd.read_csv(file_to_open)

# %%
#data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Data Types for columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Correcting year column 
df['yearcorrect'] = df['released'].astype(str).str[:4]

# %%
df.sort_values(by=['gross'], inplace = False, ascending = False)
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0           14   787
# 1   327       55   4500000.0   58853106.0      731    104.0           13   550
# 2  1745       55  18000000.0  538375067.0     1540    124.0           14   860
# 3  2246       55   3500000.0   83453539.0     1812     88.0           13   550
# 4   410       55   6000000.0   39846344.0     1777     98.0           13   607

# %%
pd.set_option('display.max_rows', None)

# %%
#drop duplicates

df.drop_duplicates()

df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0           14   787
# 1   327       55   4500000.0   58853106.0      731    104.0           13   550
# 2  1745       55  18000000.0  538375067.0     1540    124.0           14   860
# 3  2246       55   3500000.0   83453539.0     1812     88.0           13   550
# 4   410       55   6000000.0   39846344.0     1777     98.0           13   607

# %%
#outliers

df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
#scatter plot with budget vs gross revenue. 
sns.regplot(x="gross", y="budget", data=df)
# Out:
# <AxesSubplot:xlabel='gross', ylabel='budget'>

# %%
# plot budget vs gross using seaborn

sns.regplot(x='budget', y= 'gross', data = df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
correlation_matrix = df.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Gross earnings')
plt.ylabel('budget for film')
plt.show()

# %%
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000  0.143938  0.036367  0.965761  0.959015 -0.046733
# rating       0.143938  1.000000 -0.086723  0.156713  0.146606  0.012595
# genre        0.036367 -0.086723  1.000000  0.037184  0.035940 -0.002437
# year         0.965761  0.156713  0.037184  1.000000  0.993190 -0.044981
# released     0.959015  0.146606  0.035940  0.993190  1.000000 -0.045761
# score       -0.046733  0.012595 -0.002437 -0.044981 -0.045761  1.000000
# votes        0.287776  0.099972  0.023285  0.312401  0.299905 -0.009749
# director     0.745905  0.085520  0.047288  0.770497  0.770876 -0.022687
# writer       0.805211  0.103623  0.033688  0.824770  0.819617 -0.034685
# star         0.731565  0.093116  0.038649  0.756400  0.754468 -0.009896
# country      0.142828  0.000494 -0.015795  0.140216  0.148468  0.023097
# budget       0.277488  0.193353  0.073008  0.300621  0.285691 -0.012642
# gross        0.947324  0.158582  0.038616  0.980873  0.976423 -0.047041
# company      0.591667 -0.028035  0.009566  0.601571  0.607954 -0.028432
# runtime      0.048955  0.032741  0.001462  0.050647  0.048235  0.026436
# yearcorrect  0.005512 -0.023210 -0.006096  0.002813 -0.002119  0.027790
#
#                 votes  director    writer      star   country    budget  \
# name         0.287776  0.745905  0.805211  0.731565  0.142828  0.277488
# rating       0.099972  0.085520  0.103623  0.093116  0.000494  0.193353
# genre        0.023285  0.047288  0.033688  0.038649 -0.015795  0.073008
# year         0.312401  0.770497  0.824770  0.756400  0.140216  0.300621
# released     0.299905  0.770876  0.819617  0.754468  0.148468  0.285691
# score       -0.009749 -0.022687 -0.034685 -0.009896  0.023097 -0.012642
# votes        1.000000  0.192220  0.224122  0.179601 -0.045914  0.398519
# director     0.192220  1.000000  0.748340  0.682385  0.155471  0.106617
# writer       0.224122  0.748340  1.000000  0.675685  0.157202  0.187238
# star         0.179601  0.682385  0.675685  1.000000  0.182045  0.107991
# country     -0.045914  0.155471  0.157202  0.182045  1.000000 -0.082082
# budget       0.398519  0.106617  0.187238  0.107991 -0.082082  1.000000
# gross        0.286180  0.750911  0.805576  0.735680  0.133982  0.285832
# company      0.008900  0.552258  0.546151  0.527116  0.226346 -0.092249
# runtime      0.106024 -0.011070  0.032264  0.035392  0.124154  0.112097
# yearcorrect -0.050240  0.007811  0.016584  0.019895  0.018554 -0.085382
#
#                 gross   company   runtime  yearcorrect
# name         0.947324  0.591667  0.048955     0.005512
# rating       0.158582 -0.028035  0.032741    -0.023210
# genre        0.038616  0.009566  0.001462    -0.006096
# year         0.980873  0.601571  0.050647     0.002813
# released     0.976423  0.607954  0.048235    -0.002119
# score       -0.047041 -0.028432  0.026436     0.027790
# votes        0.286180  0.008900  0.106024    -0.050240
# director     0.750911  0.552258 -0.011070     0.007811
# writer       0.805576  0.546151  0.032264     0.016584
# star         0.735680  0.527116  0.035392     0.019895
# country      0.133982  0.226346  0.124154     0.018554
# budget       0.285832 -0.092249  0.112097    -0.085382
# gross        1.000000  0.588156  0.042978    -0.001597
# company      0.588156  1.000000  0.005137     0.058092
# runtime      0.042978  0.005137  1.000000    -0.036201
# yearcorrect -0.001597  0.058092 -0.036201     1.000000

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name         name           1.000000
#              rating         0.143938
#              genre          0.036367
#              year           0.965761
#              released       0.959015
#              score         -0.046733
#              votes          0.287776
#              director       0.745905
#              writer         0.805211
#              star           0.731565
#              country        0.142828
#              budget         0.277488
#              gross          0.947324
#              company        0.591667
#              runtime        0.048955
#              yearcorrect    0.005512
# rating       name           0.143938
#              rating         1.000000
#              genre         -0.086723
#              year           0.156713
#              released       0.146606
#              score          0.012595
#              votes          0.099972
#              director       0.085520
#              writer         0.103623
#              star           0.093116
#              country        0.000494
#              budget         0.193353
#              gross          0.158582
#              company       -0.028035
#              runtime        0.032741
#              yearcorrect   -0.023210
# genre        name           0.036367
#              rating        -0.086723
#              genre          1.000000
#              year           0.037184
#              released       0.035940
#              score         -0.002437
#              votes          0.023285
#              director       0.047288
#              writer         0.033688
#              star           0.038649
#              country       -0.015795
#              budget         0.073008
#              gross          0.038616
#              company        0.009566
#              runtime        0.001462
#              yearcorrect   -0.006096
# year         name           0.965761
#              rating         0.156713
#              genre          0.037184
#              year           1.000000
#              released       0.993190
#              score         -0.044981
#              votes          0.312401
#              director       0.770497
#              writer         0.824770
#              star           0.756400
#              country        0.140216
#              budget         0.300621
#              gross          0.980873
#              company        0.601571
#              runtime        0.050647
#              yearcorrect    0.002813
# released     name           0.959015
#              rating         0.146606
#              genre          0.035940
#              year           0.993190
#              released       1.000000
#              score         -0.045761
#              votes          0.299905
#              director       0.770876
#              writer         0.819617
#              star           0.754468
#              country        0.148468
#              budget         0.285691
#              gross          0.976423
#              company        0.607954
#              runtime        0.048235
#              yearcorrect   -0.002119
# score        name          -0.046733
#              rating         0.012595
#              genre         -0.002437
#              year          -0.044981
#              released      -0.045761
#              score          1.000000
#              votes         -0.009749
#              director      -0.022687
#              writer        -0.034685
#              star          -0.009896
#              country        0.023097
#              budget        -0.012642
#              gross         -0.047041
#              company       -0.028432
#              runtime        0.026436
#              yearcorrect    0.027790
# votes        name           0.287776
#              rating         0.099972
#              genre          0.023285
#              year           0.312401
#              released       0.299905
#              score         -0.009749
#              votes          1.000000
#              director       0.192220
#              writer         0.224122
#              star           0.179601
#              country       -0.045914
#              budget         0.398519
#              gross          0.286180
#              company        0.008900
#              runtime        0.106024
#              yearcorrect   -0.050240
# director     name           0.745905
#              rating         0.085520
#              genre          0.047288
#              year           0.770497
#              released       0.770876
#              score         -0.022687
#              votes          0.192220
#              director       1.000000
#              writer         0.748340
#              star           0.682385
#              country        0.155471
#              budget         0.106617
#              gross          0.750911
#              company        0.552258
#              runtime       -0.011070
#              yearcorrect    0.007811
# writer       name           0.805211
#              rating         0.103623
#              genre          0.033688
#              year           0.824770
#              released       0.819617
#              score         -0.034685
#              votes          0.224122
#              director       0.748340
#              writer         1.000000
#              star           0.675685
#              country        0.157202
#              budget         0.187238
#              gross          0.805576
#              company        0.546151
#              runtime        0.032264
#              yearcorrect    0.016584
# star         name           0.731565
#              rating         0.093116
#              genre          0.038649
#              year           0.756400
#              released       0.754468
#              score         -0.009896
#              votes          0.179601
#              director       0.682385
#              writer         0.675685
#              star           1.000000
#              country        0.182045
#              budget         0.107991
#              gross          0.735680
#              company        0.527116
#              runtime        0.035392
#              yearcorrect    0.019895
# country      name           0.142828
#              rating         0.000494
#              genre         -0.015795
#              year           0.140216
#              released       0.148468
#              score          0.023097
#              votes         -0.045914
#              director       0.155471
#              writer         0.157202
#              star           0.182045
#              country        1.000000
#              budget        -0.082082
#              gross          0.133982
#              company        0.226346
#              runtime        0.124154
#              yearcorrect    0.018554
# budget       name           0.277488
#              rating         0.193353
#              genre          0.073008
#              year           0.300621
#              released       0.285691
#              score         -0.012642
#              votes          0.398519
#              director       0.106617
#              writer         0.187238
#              star           0.107991
#              country       -0.082082
#              budget         1.000000
#              gross          0.285832
#              company       -0.092249
#              runtime        0.112097
#              yearcorrect   -0.085382
# gross        name           0.947324
#              rating         0.158582
#              genre          0.038616
#              year           0.980873
#              released       0.976423
#              score         -0.047041
#              votes          0.286180
#              director       0.750911
#              writer         0.805576
#              star           0.735680
#              country        0.133982
#              budget         0.285832
#              gross          1.000000
#              company        0.588156
#              runtime        0.042978
#              yearcorrect   -0.001597
# company      name           0.591667
#              rating        -0.028035
#              genre          0.009566
#              year           0.601571
#              released       0.607954
#              score         -0.028432
#              votes          0.008900
#              director       0.552258
#              writer         0.546151
#              star           0.527116
#              country        0.226346
#              budget        -0.092249
#              gross          0.588156
#              company        1.000000
#              runtime        0.005137
#              yearcorrect    0.058092
# runtime      name           0.048955
#              rating         0.032741
#              genre          0.001462
#              year           0.050647
#              released       0.048235
#              score          0.026436
#              votes          0.106024
#              director      -0.011070
#              writer         0.032264
#              star           0.035392
#              country        0.124154
#              budget         0.112097
#              gross          0.042978
#              company        0.005137
#              runtime        1.000000
#              yearcorrect   -0.036201
# yearcorrect  name           0.005512
#              rating        -0.023210
#              genre         -0.006096
#              year           0.002813
#              released      -0.002119
#              score          0.027790
#              votes         -0.050240
#              director       0.007811
#              writer         0.016584
#              star           0.019895
#              country        0.018554
#              budget        -0.085382
#              gross         -0.001597
#              company        0.058092
#              runtime       -0.036201
#              yearcorrect    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")
# Out:
# company      budget        -0.092249
# budget       company       -0.092249
# genre        rating        -0.086723
# rating       genre         -0.086723
# yearcorrect  budget        -0.085382
# budget       yearcorrect   -0.085382
# country      budget        -0.082082
# budget       country       -0.082082
# yearcorrect  votes         -0.050240
# votes        yearcorrect   -0.050240
# gross        score         -0.047041
# score        gross         -0.047041
# name         score         -0.046733
# score        name          -0.046733
# votes        country       -0.045914
# country      votes         -0.045914
# score        released      -0.045761
# released     score         -0.045761
# year         score         -0.044981
# score        year          -0.044981
# yearcorrect  runtime       -0.036201
# runtime      yearcorrect   -0.036201
# writer       score         -0.034685
# score        writer        -0.034685
#              company       -0.028432
# company      score         -0.028432
# rating       company       -0.028035
# company      rating        -0.028035
# rating       yearcorrect   -0.023210
# yearcorrect  rating        -0.023210
# score        director      -0.022687
# director     score         -0.022687
# country      genre         -0.015795
# genre        country       -0.015795
# score        budget        -0.012642
# budget       score         -0.012642
# director     runtime       -0.011070
# runtime      director      -0.011070
# star         score         -0.009896
# score        star          -0.009896
#              votes         -0.009749
# votes        score         -0.009749
# genre        yearcorrect   -0.006096
# yearcorrect  genre         -0.006096
# score        genre         -0.002437
# genre        score         -0.002437
# yearcorrect  released      -0.002119
# released     yearcorrect   -0.002119
# gross        yearcorrect   -0.001597
# yearcorrect  gross         -0.001597
# rating       country        0.000494
# country      rating         0.000494
# runtime      genre          0.001462
# genre        runtime        0.001462
# yearcorrect  year           0.002813
# year         yearcorrect    0.002813
# company      runtime        0.005137
# runtime      company        0.005137
# name         yearcorrect    0.005512
# yearcorrect  name           0.005512
# director     yearcorrect    0.007811
# yearcorrect  director       0.007811
# company      votes          0.008900
# votes        company        0.008900
# company      genre          0.009566
# genre        company        0.009566
# score        rating         0.012595
# rating       score          0.012595
# writer       yearcorrect    0.016584
# yearcorrect  writer         0.016584
#              country        0.018554
# country      yearcorrect    0.018554
# star         yearcorrect    0.019895
# yearcorrect  star           0.019895
# country      score          0.023097
# score        country        0.023097
# genre        votes          0.023285
# votes        genre          0.023285
# score        runtime        0.026436
# runtime      score          0.026436
# score        yearcorrect    0.027790
# yearcorrect  score          0.027790
# writer       runtime        0.032264
# runtime      writer         0.032264
#              rating         0.032741
# rating       runtime        0.032741
# genre        writer         0.033688
# writer       genre          0.033688
# star         runtime        0.035392
# runtime      star           0.035392
# released     genre          0.035940
# genre        released       0.035940
#              name           0.036367
# name         genre          0.036367
# genre        year           0.037184
# year         genre          0.037184
# gross        genre          0.038616
# genre        gross          0.038616
# star         genre          0.038649
# genre        star           0.038649
# runtime      gross          0.042978
# gross        runtime        0.042978
# genre        director       0.047288
# director     genre          0.047288
# runtime      released       0.048235
# released     runtime        0.048235
# name         runtime        0.048955
# runtime      name           0.048955
# year         runtime        0.050647
# runtime      year           0.050647
# company      yearcorrect    0.058092
# yearcorrect  company        0.058092
# budget       genre          0.073008
# genre        budget         0.073008
# director     rating         0.085520
# rating       director       0.085520
#              star           0.093116
# star         rating         0.093116
# votes        rating         0.099972
# rating       votes          0.099972
# writer       rating         0.103623
# rating       writer         0.103623
# votes        runtime        0.106024
# runtime      votes          0.106024
# budget       director       0.106617
# director     budget         0.106617
# star         budget         0.107991
# budget       star           0.107991
# runtime      budget         0.112097
# budget       runtime        0.112097
# runtime      country        0.124154
# country      runtime        0.124154
#              gross          0.133982
# gross        country        0.133982
# year         country        0.140216
# country      year           0.140216
# name         country        0.142828
# country      name           0.142828
# name         rating         0.143938
# rating       name           0.143938
# released     rating         0.146606
# rating       released       0.146606
# released     country        0.148468
# country      released       0.148468
# director     country        0.155471
# country      director       0.155471
# rating       year           0.156713
# year         rating         0.156713
# country      writer         0.157202
# writer       country        0.157202
# rating       gross          0.158582
# gross        rating         0.158582
# star         votes          0.179601
# votes        star           0.179601
# star         country        0.182045
# country      star           0.182045
# budget       writer         0.187238
# writer       budget         0.187238
# director     votes          0.192220
# votes        director       0.192220
# rating       budget         0.193353
# budget       rating         0.193353
# writer       votes          0.224122
# votes        writer         0.224122
# company      country        0.226346
# country      company        0.226346
# name         budget         0.277488
# budget       name           0.277488
#              released       0.285691
# released     budget         0.285691
# gross        budget         0.285832
# budget       gross          0.285832
# votes        gross          0.286180
# gross        votes          0.286180
# name         votes          0.287776
# votes        name           0.287776
#              released       0.299905
# released     votes          0.299905
# year         budget         0.300621
# budget       year           0.300621
# year         votes          0.312401
# votes        year           0.312401
# budget       votes          0.398519
# votes        budget         0.398519
# star         company        0.527116
# company      star           0.527116
# writer       company        0.546151
# company      writer         0.546151
#              director       0.552258
# director     company        0.552258
# company      gross          0.588156
# gross        company        0.588156
# name         company        0.591667
# company      name           0.591667
#              year           0.601571
# year         company        0.601571
# released     company        0.607954
# company      released       0.607954
# writer       star           0.675685
# star         writer         0.675685
#              director       0.682385
# director     star           0.682385
# star         name           0.731565
# name         star           0.731565
# gross        star           0.735680
# star         gross          0.735680
# name         director       0.745905
# director     name           0.745905
#              writer         0.748340
# writer       director       0.748340
# gross        director       0.750911
# director     gross          0.750911
# released     star           0.754468
# star         released       0.754468
#              year           0.756400
# year         star           0.756400
#              director       0.770497
# director     year           0.770497
#              released       0.770876
# released     director       0.770876
# name         writer         0.805211
# writer       name           0.805211
#              gross          0.805576
# gross        writer         0.805576
# writer       released       0.819617
# released     writer         0.819617
# writer       year           0.824770
# year         writer         0.824770
# name         gross          0.947324
# gross        name           0.947324
# released     name           0.959015
# name         released       0.959015
# year         name           0.965761
# name         year           0.965761
# released     gross          0.976423
# gross        released       0.976423
#              year           0.980873
# year         gross          0.980873
# released     year           0.993190
# year         released       0.993190
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#high correlation pairs
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# star         company        0.527116
# company      star           0.527116
# writer       company        0.546151
# company      writer         0.546151
#              director       0.552258
# director     company        0.552258
# company      gross          0.588156
# gross        company        0.588156
# name         company        0.591667
# company      name           0.591667
#              year           0.601571
# year         company        0.601571
# released     company        0.607954
# company      released       0.607954
# writer       star           0.675685
# star         writer         0.675685
#              director       0.682385
# director     star           0.682385
# star         name           0.731565
# name         star           0.731565
# gross        star           0.735680
# star         gross          0.735680
# name         director       0.745905
# director     name           0.745905
#              writer         0.748340
# writer       director       0.748340
# gross        director       0.750911
# director     gross          0.750911
# released     star           0.754468
# star         released       0.754468
#              year           0.756400
# year         star           0.756400
#              director       0.770497
# director     year           0.770497
#              released       0.770876
# released     director       0.770876
# name         writer         0.805211
# writer       name           0.805211
#              gross          0.805576
# gross        writer         0.805576
# writer       released       0.819617
# released     writer         0.819617
# writer       year           0.824770
# year         writer         0.824770
# name         gross          0.947324
# gross        name           0.947324
# released     name           0.959015
# name         released       0.959015
# year         name           0.965761
# name         year           0.965761
# released     gross          0.976423
# gross        released       0.976423
#              year           0.980873
# year         gross          0.980873
# released     year           0.993190
# year         released       0.993190
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# top 15 companies by gross revenue
CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
df['Year'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0           14  1705
# 1   327       55   4500000.0   58853106.0      731    104.0           13  1492
# 2  1745       55  18000000.0  538375067.0     1540    124.0           14  1771
# 3  2246       55   3500000.0   83453539.0     1812     88.0           13  1492
# 4   410       55   6000000.0   39846344.0     1777     98.0           13  1543

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2010    3300479986
#                        2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df_numerized = df.head()


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0           14   787
# 1   327       55   4500000.0   58853106.0      731    104.0           13   550
# 2  1745       55  18000000.0  538375067.0     1540    124.0           14   860
# 3  2246       55   3500000.0   83453539.0     1812     88.0           13   550
# 4   410       55   6000000.0   39846344.0     1777     98.0           13   607

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

# %%
sns.swarmplot(x="rating", y="gross", data=df)
# Out:
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 53.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 48.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 60.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 80.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 84.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 88.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 94.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/zoya/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 76.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='rating', ylabel='gross'>
